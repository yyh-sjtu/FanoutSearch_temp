# %%
import verilog_reader_package as vr
import pandas as pd
import numpy as np

# %%
file_name='./verilog_netlist_for_test/test2.v'
txt=vr.read_file(file_name)

# %%
input_list,output_list,node_list,index_node,node_wire_insub,node_wire_outsub,module_name=vr.netlist_extract(txt)

# %%
node_wiredf=pd.DataFrame([node_list,node_wire_insub,node_wire_outsub]).T
node_wiredf = node_wiredf.rename(columns={0: 'node', 1: 'port', 2: 'wire'})

# %%
node_wiredf.to_csv('node_wiredf.csv')
node_wiredf
# Out:
#                                  node                     port
# 0           sky130_fd_sc_hd__buf_2 U0                   [A, X]  \
# 1           sky130_fd_sc_hd__buf_1 U1                   [A, X]
# 2          sky130_fd_sc_hd__buf_1 U10                   [A, X]
# 3         sky130_fd_sc_hd__or3_2 U100             [A, B, C, X]
# 4     sky130_fd_sc_hd__o21bai_2 U1000        [A1, A2, B1_N, Y]
# ...                               ...                      ...
# 1249    sky130_fd_sc_hd__o221a_2 U995  [A1, A2, B1, B2, C1, X]
# 1250    sky130_fd_sc_hd__o21ai_2 U996          [A1, A2, B1, Y]
# 1251    sky130_fd_sc_hd__a21oi_2 U997          [A1, A2, B1, Y]
# 1252    sky130_fd_sc_hd__nand2_2 U998                [A, B, Y]
# 1253    sky130_fd_sc_hd__a21oi_2 U999          [A1, A2, B1, Y]
#
#                                               wire
# 0                     [o_flags[2], o_quotient[31]]
# 1                            [o_quotient[0], n553]
# 2                                     [n561, n562]
# 3     [o_quotient[22], o_quotient[23], n627, n632]
# 4                         [n794, n453, n685, n454]
# ...                                            ...
# 1249          [n435, n299, n446, n449, n368, n129]
# 1250          [i_numerator[23], n261, n1032, n450]
# 1251                      [n437, n439, n794, n451]
# 1252                            [n451, n685, n452]
# 1253                      [n441, n442, n686, n453]
#
# [1254 rows x 3 columns]

# %%
adj_mat=vr.adj_generator(input_list,index_node,node_wire_outsub)
np.savetxt("adj.txt",adj_mat,fmt="%d", delimiter=",")
adj_mat_pd=pd.DataFrame(adj_mat)
adj_mat_pd.to_csv('adj_mat.csv')

# %%
graph=vr.Mygraph(len(adj_mat[0]),adj_mat)

# %%
print(graph.getMatrixValue)
# Out:
# <bound method Mygraph.getMatrixValue of <verilog_reader_package.Mygraph object at 0x000002BF4395ABF0>>

# %%
dic_in,dic_out=vr.node2io(input_list,output_list,index_node,node_wire_outsub)

# %%
dic_in
# Out:
# {'i_clk': [127,
#   128,
#   129,
#   130,
#   131,
#   132,
#   133,
#   134,
#   135,
#   137,
#   138,
#   139,
#   140,
#   141,
#   142,
#   143,
#   144,
#   145,
#   146,
#   148,
#   149,
#   150,
#   151,
#   152,
#   153,
#   154,
#   155,
#   156,
#   157,
#   159,
#   160,
#   161,
#   162,
#   163,
#   164,
#   165,
#   166,
#   167,
#   168,
#   170,
#   171,
#   172,
#   173,
#   174,
#   175,
#   176,
#   177,
#   178,
#   179,
#   181,
#   182,
#   183,
#   184,
#   185,
#   186,
#   187,
#   188,
#   189,
#   190,
#   192,
#   193,
#   194,
#   195,
#   196,
#   197,
#   198,
#   199,
#   200,
#   201,
#   203,
#   204,
#   205,
#   206,
#   207,
#   208,
#   209,
#   210,
#   211,
#   212,
#   214,
#   215,
#   216,
#   217,
#   218,
#   219,
#   220,
#   221,
#   222,
#   223,
#   226,
#   227,
#   228,
#   229,
#   230,
#   231,
#   232,
#   233,
#   234,
#   235,
#   237,
#   238,
#   239,
#   240,
#   241,
#   242,
#   243,
#   244,
#   245,
#   246,
#   248,
#   249,
#   250,
#   251,
#   252,
#   253,
#   254,
#   255,
#   256,
#   257,
#   259,
#   260,
#   261,
#   262,
#   263,
#   264,
#   265,
#   266,
#   267,
#   268,
#   270,
#   271,
#   272,
#   273,
#   274,
#   275,
#   276,
#   277,
#   278,
#   279,
#   281,
#   282,
#   283],
#  'i_denominator[0]': [704, 723],
#  'i_denominator[1]': [704, 752],
#  'i_denominator[2]': [704, 761],
#  'i_denominator[3]': [706, 772],
#  'i_denominator[4]': [706, 778],
#  'i_denominator[5]': [706, 790],
#  'i_denominator[6]': [706, 796],
#  'i_denominator[7]': [705, 804],
#  'i_denominator[8]': [705, 812],
#  'i_denominator[9]': [705, 819],
#  'i_denominator[10]': [705, 825],
#  'i_denominator[11]': [708, 834],
#  'i_denominator[12]': [708, 840],
#  'i_denominator[13]': [708, 849],
#  'i_denominator[14]': [708, 854],
#  'i_denominator[15]': [707, 862],
#  'i_denominator[16]': [707, 868],
#  'i_denominator[17]': [707, 874],
#  'i_denominator[18]': [707, 880],
#  'i_denominator[19]': [703, 885],
#  'i_denominator[20]': [703, 892],
#  'i_denominator[21]': [703, 898],
#  'i_denominator[22]': [703, 902],
#  'i_denominator[23]': [702, 912],
#  'i_denominator[24]': [702, 917],
#  'i_denominator[25]': [702, 924],
#  'i_denominator[26]': [702, 927],
#  'i_denominator[27]': [701, 934],
#  'i_denominator[28]': [701, 936],
#  'i_denominator[29]': [701, 946],
#  'i_denominator[30]': [701, 951],
#  'i_denominator[31]': [664, 704, 747],
#  'i_numerator[0]': [726],
#  'i_numerator[1]': [967],
#  'i_numerator[2]': [975],
#  'i_numerator[3]': [1000],
#  'i_numerator[4]': [1015],
#  'i_numerator[5]': [1028],
#  'i_numerator[6]': [1039],
#  'i_numerator[7]': [1053],
#  'i_numerator[8]': [1059],
#  'i_numerator[9]': [1071],
#  'i_numerator[10]': [1086],
#  'i_numerator[11]': [1100],
#  'i_numerator[12]': [1113],
#  'i_numerator[13]': [1120],
#  'i_numerator[14]': [1130],
#  'i_numerator[15]': [1150],
#  'i_numerator[16]': [1164],
#  'i_numerator[17]': [1167],
#  'i_numerator[18]': [1189],
#  'i_numerator[19]': [1203],
#  'i_numerator[20]': [1217],
#  'i_numerator[21]': [1226],
#  'i_numerator[22]': [1245],
#  'i_numerator[23]': [1250],
#  'i_numerator[24]': [16],
#  'i_numerator[25]': [22],
#  'i_numerator[26]': [44],
#  'i_numerator[27]': [56],
#  'i_numerator[28]': [62],
#  'i_numerator[29]': [79],
#  'i_numerator[30]': [94],
#  'i_numerator[31]': [560, 664],
#  'i_reset': [660, 669, 710, 745, 921],
#  'i_signed': [664],
#  'i_wr': [647, 664, 698, 710, 717, 718],
#  'o_flags[0]': [194, 647],
#  'o_flags[1]': [279],
#  'o_flags[2]': [0, 157, 288, 290],
#  'o_flags[3]': [284],
#  'o_quotient[0]': [1, 281, 500],
#  'o_quotient[1]': [121, 124, 126, 282, 477, 500, 588],
#  'o_quotient[2]': [124, 283, 300, 477, 500, 588],
#  'o_quotient[3]': [127, 366, 511],
#  'o_quotient[4]': [128, 311, 333, 355, 367, 378, 511],
#  'o_quotient[5]': [129, 355, 367, 455, 466, 478, 511],
#  'o_quotient[6]': [130, 455, 466, 489, 533, 555, 577],
#  'o_quotient[7]': [131, 489, 522, 577, 611],
#  'o_quotient[8]': [132, 566, 766],
#  'o_quotient[9]': [133, 622, 766],
#  'o_quotient[10]': [134, 666, 811],
#  'o_quotient[11]': [135, 722, 733, 755, 766, 788],
#  'o_quotient[12]': [137, 755, 766, 844],
#  'o_quotient[13]': [138, 799, 822, 866, 877, 899, 922],
#  'o_quotient[14]': [139, 855, 1088],
#  'o_quotient[15]': [140, 910, 1088],
#  'o_quotient[16]': [141, 955, 1099],
#  'o_quotient[17]': [142, 1010, 1021, 1044, 1055, 1066, 1099],
#  'o_quotient[18]': [143, 1044, 1055, 1077, 1099, 1121, 1144],
#  'o_quotient[19]': [144, 1077, 1099, 1144, 1155, 1166],
#  'o_quotient[20]': [114, 145, 1132],
#  'o_quotient[21]': [114, 146, 1177, 1188, 1221, 1243],
#  'o_quotient[22]': [3, 14, 25, 102, 148, 1210, 1221],
#  'o_quotient[23]': [3, 14, 58, 69, 80, 102, 149],
#  'o_quotient[24]': [58, 69, 91, 102, 136, 150],
#  'o_quotient[25]': [91, 102, 151, 169],
#  'o_quotient[26]': [147, 152, 158, 180, 191, 202, 225],
#  'o_quotient[27]': [153, 180, 191, 213, 225, 236],
#  'o_quotient[28]': [154, 213, 225, 269, 280, 285],
#  'o_quotient[29]': [155, 258, 269, 285, 286, 287, 290],
#  'o_quotient[30]': [156, 285, 286, 290, 291],
#  'o_quotient[31]': [0]}

# %%
dic_out
# Out:
# {'o_busy': [206, 714], 'o_err': [210], 'o_valid': [204, 690]}

# %%
graph.getPathofTwoNode(156,206) #dic_in 和 dic_out里面存有与输入输出端口相连的node，请将与输入相连的一个node的编号和与输出端口相连的一个node的编号作为参数
# Out:
# 找到一条路径
# [156, 287, 69, 58, 1221, 125, 114, 102, 147, 3, 14, 25, 91, 136, 169, 158, 1177, 1110, 833, 533, 544, 555, 202, 180, 191, 225, 236, 258, 2, 120, 1, 122, 67, 64, 29, 19, 17, 6, 7, 8, 5, 4, 101, 74, 59, 60, 61, 63, 43, 42, 38, 37, 11, 13, 10, 12, 385, 369, 359, 184, 338, 183, 337, 182, 336, 181, 335, 179, 332, 178, 329, 177, 328, 176, 327, 175, 326, 174, 325, 173, 323, 172, 319, 171, 318, 170, 317, 168, 316, 167, 315, 166, 313, 165, 308, 164, 307, 163, 306, 162, 305, 161, 304, 160, 302, 159, 419, 109, 110, 111, 112, 115, 116, 108, 106, 470, 370, 265, 373, 374, 371, 266, 372, 473, 384, 383, 376, 375, 264, 377, 379, 472, 471, 380, 263, 382, 615, 469, 1191, 1153, 1156, 351, 196, 292, 293, 95, 81, 27, 22, 79, 94, 1128, 62, 55, 26, 23, 15, 16, 21, 20, 18, 28, 46, 32, 33, 34, 35, 45, 44, 56, 57, 48, 49, 86, 84, 65, 66